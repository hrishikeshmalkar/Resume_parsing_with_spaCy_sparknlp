# %% [markdown]
# <a href="https://colab.research.google.com/github/hrishikeshmalkar/Resume_parsing_with_spaCy_sparknlp/blob/main/Resume_parser_spaCy_Spark_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Resume Parser using spaCy and Spark-NLP**
# #### --- By Hrishikesh Malkar

# %% [markdown]
# ##### Importing Required Liberaries

# %%
import pandas as pd
import spacy
import pickle
import random
import re
import json
import random
import logging

# %% [markdown]
# ##### Reading data

# %%
df = pd.read_json('Entity Recognition in Resumes.json', lines=True)

# %% [markdown]
# ##### Preview of Data

# %%
df.head(5)
# Out:
#                                              content  ... extras
# 0  Abhishek Jha\nApplication Development Associat...  ...    NaN
# 1  Afreen Jamadar\nActive member of IIIT Committe...  ...    NaN
# 2  Akhil Yadav Polemaina\nHyderabad, Telangana - ...  ...    NaN
# 3  Alok Khandai\nOperational Analyst (SQL DBA) En...  ...    NaN
# 4  Ananya Chavan\nlecturer - oracle tutorials\n\n...  ...    NaN
#
# [5 rows x 3 columns]

# %% [markdown]
# ##### Removing '/n' characters from data. (i.e. New Line Character)

# %%
for i in range(len(df)):
    df["content"][i] = df["content"][i].replace("\n", " ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ##### Preview after removing new line characters

# %%
df.head()
# Out:
#                                              content  ... extras
# 0  Abhishek Jha Application Development Associate...  ...    NaN
# 1  Afreen Jamadar Active member of IIIT Committee...  ...    NaN
# 2  Akhil Yadav Polemaina Hyderabad, Telangana - E...  ...    NaN
# 3  Alok Khandai Operational Analyst (SQL DBA) Eng...  ...    NaN
# 4  Ananya Chavan lecturer - oracle tutorials  Mum...  ...    NaN
#
# [5 rows x 3 columns]

# %% [markdown]
# ##### Function for Converting DataFrame into required format. (i.e. Datatrucks to spaCy)

# %%
def convert_to_spacy(JSON_FilePath):
    try:
        training_data = []
        lines=[]
        with open(JSON_FilePath,encoding="utf8") as f:
            lines = f.readlines()

        for line in lines:
            data = json.loads(line)
            text = data['content'].replace("\n", " ")
            entities = []
            data_annotations = data['annotation']
            if data_annotations is not None:
                for annotation in data_annotations:
                    #only a single point in text annotation.
                    point = annotation['points'][0]
                    labels = annotation['label']
                    # handle both list of labels or a single label.
                    if not isinstance(labels, list):
                        labels = [labels]

                    for label in labels:
                        point_start = point['start']
                        point_end = point['end']
                        point_text = point['text']
                        
                        lstrip_diff = len(point_text) - len(point_text.lstrip())
                        rstrip_diff = len(point_text) - len(point_text.rstrip())
                        if lstrip_diff != 0:
                            point_start = point_start + lstrip_diff
                        if rstrip_diff != 0:
                            point_end = point_end - rstrip_diff
                        entities.append((point_start, point_end + 1 , label))
            training_data.append((text, {"entities" : entities}))
        return training_data
    except Exception as e:
        logging.exception("Unable to process " + JSON_FilePath + "\n" + "error = " + str(e))
        return None

# %% [markdown]
# ##### Function for Removing leading & trailing white spaces from entity spans.
#
#
# > **Args: data (list)**: The data to be cleaned in spaCy JSON format.
#
# > **Returns: list**: The cleaned data and stored it in a List.

# %%
def trim_entity_spans(data: list) -> list:
    invalid_span_tokens = re.compile(r'\s')

    cleaned_data = []
    for text, annotations in data:
        entities = annotations['entities']
        valid_entities = []
        for start, end, label in entities:
            valid_start = start
            valid_end = end
            while valid_start < len(text) and invalid_span_tokens.match(
                    text[valid_start]):
                valid_start += 1
            while valid_end > 1 and invalid_span_tokens.match(
                    text[valid_end - 1]):
                valid_end -= 1
            valid_entities.append([valid_start, valid_end, label])
        cleaned_data.append([text, {'entities': valid_entities}])
    return cleaned_data

# %% [markdown]
# ##### Converting our Data in Required Format

# %%
conv_data=convert_to_spacy('Entity Recognition in Resumes.json')

# %% [markdown]
# ##### Preview of sample cleaned data in our required format

# %%
data = trim_entity_spans(conv_data)
data[0]
# Out:
# ["Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company's growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)  ADDITIONAL INFORMATION  Technical Skills  https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN   • Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player",
#  {'entities': [[1296, 1622, 'Skills'],
#    [993, 1154, 'Skills'],
#    [939, 957, 'College Name'],
#    [883, 905, 'College Name'],
#    [856, 860, 'Graduation Year'],
#    [771, 814, 'College Name'],
#    [727, 769, 'Designation'],
#    [407, 416, 'Companies worked at'],
#    [372, 405, 'Designation'],
#    [95, 145, 'Email Address'],
#    [60, 69, 'Location'],
#    [49, 58, 'Companies worked at'],
#    [13, 46, 'Designation'],
#    [0, 12, 'Name']]}]

# %% [markdown]
# #####Creating NLP Blank Model with the help of spaCy

# %%
nlp = spacy.blank('en')

# %% [markdown]
# ##### Function for training our model

# %%
def train_model(train_data):
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last = True)
    
        for _, annotation in train_data:
            for ent in annotation['entities']:
                ner.add_label(ent[2])
            
    
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(50):
            print("Statring iteration " + str(itn))
            random.shuffle(train_data)
            losses = {}
            index = 0
            for text, annotations in train_data:
                try:
                    nlp.update(
                        [text],  # batch of texts
                        [annotations],  # batch of annotations
                        drop=0.2,  # dropout - make it harder to memorise data
                        sgd=optimizer,  # callable to update weights
                        losses=losses)
                except Exception as e:
                    pass
                
            print(losses)

# %% [markdown]
# ##### Model Training

# %%
train_model(data)
# Out:
# Statring iteration 0
# {'ner': 16465.25536238796}
# Statring iteration 1
# {'ner': 15781.170626723966}
# Statring iteration 2
# {'ner': 11655.217217006186}
# Statring iteration 3
# {'ner': 10356.949478027476}
# Statring iteration 4
# {'ner': 9056.847333362526}
# Statring iteration 5
# {'ner': 8167.247733932967}
# Statring iteration 6
# {'ner': 7052.855012010317}
# Statring iteration 7
# {'ner': 7046.052151583607}
# Statring iteration 8
# {'ner': 7772.087388741171}
# Statring iteration 9
# {'ner': 5940.375102305628}
# Statring iteration 10
# {'ner': 6444.602800411875}
# Statring iteration 11
# {'ner': 6142.710391694642}
# Statring iteration 12
# {'ner': 5186.33132863332}
# Statring iteration 13
# {'ner': 5560.764955562939}
# Statring iteration 14
# {'ner': 6170.0963053789765}
# Statring iteration 15
# {'ner': 4828.416610520465}
# Statring iteration 16
# {'ner': 5565.6608713211435}
# Statring iteration 17
# {'ner': 5056.673536251201}
# Statring iteration 18
# {'ner': 5082.950300696691}
# Statring iteration 19
# {'ner': 4034.710897199544}
# Statring iteration 20
# {'ner': 4589.742429706733}
# Statring iteration 21
# {'ner': 4438.26305891931}
# Statring iteration 22
# {'ner': 4043.318334084872}
# Statring iteration 23
# {'ner': 3963.651861592451}
# Statring iteration 24
# {'ner': 3662.172464103852}
# Statring iteration 25
# {'ner': 3582.879711470454}
# Statring iteration 26
# {'ner': 3093.1284682242563}
# Statring iteration 27
# {'ner': 3313.1372967248653}
# Statring iteration 28
# {'ner': 3266.514954736389}
# Statring iteration 29
# {'ner': 3665.259584765983}
# Statring iteration 30
# {'ner': 3629.85912625732}
# Statring iteration 31
# {'ner': 3179.764756746061}
# Statring iteration 32
# {'ner': 4143.198359601254}
# Statring iteration 33
# {'ner': 2828.998222838948}
# Statring iteration 34
# {'ner': 2866.1264747225587}
# Statring iteration 35
# {'ner': 3147.20021126565}
# Statring iteration 36
# {'ner': 3358.9560585790687}
# Statring iteration 37
# {'ner': 2870.7526950256297}
# Statring iteration 38
# {'ner': 2699.914646538792}
# Statring iteration 39
# {'ner': 3324.847127865882}
# Statring iteration 40
# {'ner': 3206.3280063153907}
# Statring iteration 41
# {'ner': 2401.566056977986}
# Statring iteration 42
# {'ner': 2328.354032614819}
# Statring iteration 43
# {'ner': 2230.510462487565}
# Statring iteration 44
# {'ner': 2587.0250681196426}
# Statring iteration 45
# {'ner': 2771.7990320445233}
# Statring iteration 46
# {'ner': 2403.2027996094275}
# Statring iteration 47
# {'ner': 2433.393709463683}
# Statring iteration 48
# {'ner': 1857.3781942706007}
# Statring iteration 49
# {'ner': 2329.9786575961843}

# %% [markdown]
# ##### Saving our model into disk.

# %%
nlp.to_disk('/content/my_nlp_model')

# %% [markdown]
# ##### Loading Saved Model with the help of spaCy

# %%
nlp_model = spacy.load('my_nlp_model')

# %% [markdown]
# ##### Model Testing

# %%
data[1][0]
# Out:
# "Nazish Alam Consultant - SAP ABAP  Ghaziabad, Uttar Pradesh - Email me on Indeed: indeed.com/r/Nazish-Alam/ b06dbac9d6236221  Willing to relocate to: Delhi, Delhi - Noida, Uttar Pradesh - Lucknow, Uttar Pradesh  WORK EXPERIENCE  Consultant  SAP ABAP -  Noida, Uttar Pradesh -  November 2016 to Present  Credence Systems, Noida  Credence Systems is IT Infrastructure Management Company, offers end-to-end solutions. Combining deep domain expertise with new technologies and a cost effective on-site/ offshore model. Helping companies integrate key business processes, improving their operational efficiencies and extracting, better business value from their investment.  PROJECT UNDERTAKEN Client ECC Version Role and Responsibilities Welspun Group Plate & Coil Mills Division SAP ECC 6.0  Consultant  SAP ABAP -  January 2016 to Present  Reports: • Designed technical program specifications based on business requirements. • Generated basic lists and Interactive Reports for information in the MM/SD including Sales, Billing, Purchasing, Goods Received, Inspection Plan, and Batch Determination using ABAP programs, Screen, Report Painter and Menu Painters. Used Parameters, Select-options and Match Codes to make the reports more friendly and intuitive to the user. • Generated different kind of reports like for PR (Purchase Requisition) analysis using ALV, PO (Purchase Order) Pricing details, Pending Export Sales order etc. • Developed report for the daily production done. SAP Scripts: • Generated various client specific Layout sets and form letters using SAP Script. • Involved in modification of SAP scripts for Purchase orders (MEDRUCK) and indents, Delivery notes (RVDELNOTE), and Invoices (RVINVOICE) according to customer needs. • Modified existing layout sets for Purchase Order and GR using SAP Script. Data Migration:  https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN   • Implemented both Call Transaction and Session Method of BDC accordingly, depending upon the size, type, state and created routines for data upload using data extracts for sequential files on the application server and UPLOAD/WS_UPLOAD for local files on the presentation server. • Wrote ABAP programs for extracting data from SAP tables (Vendor master, Purchase Orders, Invoices and remittance) to be transferred to vendors using non-SAP systems for reconciliation and their local use. Object Oriented: • Created local and global classes with SE24 and within programs. • Used the Standard ALV classes in OOPs ALV reports. • Used ABSTRACT classes and Interfaces. • Having knowledge and used the different object oriented concepts technically.  SKILLS  SAP (2 years), ABAP (2 years), ADBC (Less than 1 year), C++ (Less than 1 year), DATA MODELING (Less than 1 year)  ADDITIONAL INFORMATION  OTHER TECHNICAL SKILLS • Trained on SAP S4 HANA. • Having knowledge of Code Push down, CDS view and it's consumption in ABAP. • Data Modeling, creation of different type of views. • AMDP. • ADBC connectivity. • Familiar with SQL, DDL, DML syntaxes. • Work on Windows 7, Windows XP, Windows 8, Windows 10 OS, can work on C, C++ ACADEMEIC CREDENTIALS 2015 Master of Computer Application UPTU. India"

# %% [markdown]
# ##### Function for cleaning text data

# %%
def clean_data(df):
    clean_df = re.sub(r"[\(\[].*?[\)\]]", "", df)
    return (clean_df)

# %%
data1=clean_data(data[1][0])
doc = nlp_model(data1)

# %% [markdown]
# ##### Using Displacy

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nazish Alam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Name</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Consultant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Designation</span>
# </mark>
#  -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAP ABAP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Companies worked at</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ghaziabad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Location</span>
# </mark>
# , Uttar Pradesh - Email me on Indeed:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     indeed.com/r/Nazish-Alam/ b06dbac9d6236221
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Email Address</span>
# </mark>
#   Willing to relocate to: Delhi, Delhi - Noida, Uttar Pradesh - Lucknow, Uttar Pradesh  WORK EXPERIENCE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Consultant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Designation</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAP ABAP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Companies worked at</span>
# </mark>
#  -  Noida, Uttar Pradesh -  November 2016 to Present  Credence Systems, Noida  Credence Systems is IT Infrastructure Management Company, offers end-to-end solutions. Combining deep domain expertise with new technologies and a cost effective on-site/ offshore model. Helping companies integrate key business processes, improving their operational efficiencies and extracting, better business value from their investment.  PROJECT UNDERTAKEN Client ECC Version Role and Responsibilities Welspun Group Plate &amp; Coil Mills Division SAP ECC 6.0
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Consultant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Designation</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAP ABAP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Companies worked at</span>
# </mark>
#  -  January 2016 to Present  Reports: • Designed technical program specifications based on business requirements. • Generated basic lists and Interactive Reports for information in the MM/SD including Sales, Billing, Purchasing, Goods Received, Inspection Plan, and Batch Determination using ABAP programs, Screen, Report Painter and Menu Painters. Used Parameters, Select-options and Match Codes to make the reports more friendly and intuitive to the user. • Generated different kind of reports like for PR  analysis using ALV, PO  Pricing details, Pending Export Sales order etc. • Developed report for the daily production done. SAP Scripts: • Generated various client specific Layout sets and form letters using SAP Script. • Involved in modification of SAP scripts for Purchase orders  and indents, Delivery notes , and Invoices  according to customer needs. • Modified existing layout sets for Purchase Order and GR using SAP Script. Data Migration:  https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&amp;ikw=download-top&amp;co=IN https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&amp;ikw=download-top&amp;co=IN   • Implemented both Call Transaction and Session Method of BDC accordingly, depending upon the size, type, state and created routines for data upload using data extracts for sequential files on the application server and UPLOAD/WS_UPLOAD for local files on the presentation server. • Wrote ABAP programs for extracting data from SAP tables  to be transferred to vendors using non-SAP systems for reconciliation and their local use. Object Oriented: • Created local and global classes with SE24 and within programs. • Used the Standard ALV classes in OOPs ALV reports. • Used ABSTRACT classes and Interfaces. • Having knowledge and used the different object oriented concepts technically.  SKILLS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SAP , ABAP , ADBC , C++ , DATA MODELING
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#    ADDITIONAL INFORMATION  OTHER TECHNICAL SKILLS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     • Trained on SAP S4 HANA. • Having knowledge of Code Push down, CDS view and it's consumption in ABAP. • Data Modeling, creation of different type of views. • AMDP. • ADBC connectivity. • Familiar with SQL, DDL, DML syntaxes. • Work on Windows 7, Windows XP, Windows 8, Windows 10 OS, can work on C, C++
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Skills</span>
# </mark>
#  ACADEMEIC CREDENTIALS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Graduation Year</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Master of Computer Application
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Degree</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UPTU. India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">College Name</span>
# </mark>
# </div></span>

# %% [markdown]
# #####Getting Entities

# %%
for ent in doc.ents:
    print(f'{ent.label_.upper():{30}}- {ent.text}')
# Out:
# NAME                          - Nazish Alam
# DESIGNATION                   - Consultant
# COMPANIES WORKED AT           - SAP ABAP
# LOCATION                      - Ghaziabad
# EMAIL ADDRESS                 - indeed.com/r/Nazish-Alam/ b06dbac9d6236221
# DESIGNATION                   - Consultant
# COMPANIES WORKED AT           - SAP ABAP
# DESIGNATION                   - Consultant
# COMPANIES WORKED AT           - SAP ABAP
# SKILLS                        - SAP , ABAP , ADBC , C++ , DATA MODELING
# SKILLS                        - • Trained on SAP S4 HANA. • Having knowledge of Code Push down, CDS view and it's consumption in ABAP. • Data Modeling, creation of different type of views. • AMDP. • ADBC connectivity. • Familiar with SQL, DDL, DML syntaxes. • Work on Windows 7, Windows XP, Windows 8, Windows 10 OS, can work on C, C++
# GRADUATION YEAR               - 2015
# DEGREE                        - Master of Computer Application
# COLLEGE NAME                  - UPTU. India

# %% [markdown]
# #**Spark-NLP**

# %% [markdown]
# ##### Installing dependencies

# %%
# !pip install spark-nlp==3.0.0
# !pip install pyspark
# Out:
# Requirement already satisfied: spark-nlp==3.0.0 in /usr/local/lib/python3.7/dist-packages (3.0.0)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.1.1)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9)

# %% [markdown]
# ##### Importing Required Libraries

# %%
import sparknlp
from sparknlp.base import *
from sparknlp.annotator import *

# %% [markdown]
# ##### Starting Sparknlp session

# %%
spark = sparknlp.start()

# %% [markdown]
# ##### Preview of Sample Data

# %%
data[1][0]
# Out:
# "Nazish Alam Consultant - SAP ABAP  Ghaziabad, Uttar Pradesh - Email me on Indeed: indeed.com/r/Nazish-Alam/ b06dbac9d6236221  Willing to relocate to: Delhi, Delhi - Noida, Uttar Pradesh - Lucknow, Uttar Pradesh  WORK EXPERIENCE  Consultant  SAP ABAP -  Noida, Uttar Pradesh -  November 2016 to Present  Credence Systems, Noida  Credence Systems is IT Infrastructure Management Company, offers end-to-end solutions. Combining deep domain expertise with new technologies and a cost effective on-site/ offshore model. Helping companies integrate key business processes, improving their operational efficiencies and extracting, better business value from their investment.  PROJECT UNDERTAKEN Client ECC Version Role and Responsibilities Welspun Group Plate & Coil Mills Division SAP ECC 6.0  Consultant  SAP ABAP -  January 2016 to Present  Reports: • Designed technical program specifications based on business requirements. • Generated basic lists and Interactive Reports for information in the MM/SD including Sales, Billing, Purchasing, Goods Received, Inspection Plan, and Batch Determination using ABAP programs, Screen, Report Painter and Menu Painters. Used Parameters, Select-options and Match Codes to make the reports more friendly and intuitive to the user. • Generated different kind of reports like for PR (Purchase Requisition) analysis using ALV, PO (Purchase Order) Pricing details, Pending Export Sales order etc. • Developed report for the daily production done. SAP Scripts: • Generated various client specific Layout sets and form letters using SAP Script. • Involved in modification of SAP scripts for Purchase orders (MEDRUCK) and indents, Delivery notes (RVDELNOTE), and Invoices (RVINVOICE) according to customer needs. • Modified existing layout sets for Purchase Order and GR using SAP Script. Data Migration:  https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN   • Implemented both Call Transaction and Session Method of BDC accordingly, depending upon the size, type, state and created routines for data upload using data extracts for sequential files on the application server and UPLOAD/WS_UPLOAD for local files on the presentation server. • Wrote ABAP programs for extracting data from SAP tables (Vendor master, Purchase Orders, Invoices and remittance) to be transferred to vendors using non-SAP systems for reconciliation and their local use. Object Oriented: • Created local and global classes with SE24 and within programs. • Used the Standard ALV classes in OOPs ALV reports. • Used ABSTRACT classes and Interfaces. • Having knowledge and used the different object oriented concepts technically.  SKILLS  SAP (2 years), ABAP (2 years), ADBC (Less than 1 year), C++ (Less than 1 year), DATA MODELING (Less than 1 year)  ADDITIONAL INFORMATION  OTHER TECHNICAL SKILLS • Trained on SAP S4 HANA. • Having knowledge of Code Push down, CDS view and it's consumption in ABAP. • Data Modeling, creation of different type of views. • AMDP. • ADBC connectivity. • Familiar with SQL, DDL, DML syntaxes. • Work on Windows 7, Windows XP, Windows 8, Windows 10 OS, can work on C, C++ ACADEMEIC CREDENTIALS 2015 Master of Computer Application UPTU. India"

# %% [markdown]
# ##### Creating Spark DataFrame

# %%
data2= spark.createDataFrame([[data[1][0]]]).toDF('text')

# %%
data2.show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Nazish Alam Consultant - SAP ABAP  Ghaziabad, Uttar Pradesh - Email me on Indeed: indeed.com/r/Nazish-Alam/ b06dbac9d6236221  Willing to relocate to: Delhi, Delhi - Noida, Uttar Pradesh - Lucknow, Uttar Pradesh  WORK EXPERIENCE  Consultant  SAP ABAP -  Noida, Uttar Pradesh -  November 2016 to Present  Credence Systems, Noida  Credence Systems is IT Infrastructure Management Company, offers end-to-end solutions. Combining deep domain expertise with new technologies and a cost effective on-site/ offshore model. Helping companies integrate key business processes, improving their operational efficiencies and extracting, better business value from their investment.  PROJECT UNDERTAKEN Client ECC Version Role and Responsibilities Welspun Group Plate & Coil Mills Division SAP ECC 6.0  Consultant  SAP ABAP -  January 2016 to Present  Reports: • Designed technical program specifications based on business requirements. • Generated basic lists and Interactive Reports for information in the MM/SD including Sales, Billing, Purchasing, Goods Received, Inspection Plan, and Batch Determination using ABAP programs, Screen, Report Painter and Menu Painters. Used Parameters, Select-options and Match Codes to make the reports more friendly and intuitive to the user. • Generated different kind of reports like for PR (Purchase Requisition) analysis using ALV, PO (Purchase Order) Pricing details, Pending Export Sales order etc. • Developed report for the daily production done. SAP Scripts: • Generated various client specific Layout sets and form letters using SAP Script. • Involved in modification of SAP scripts for Purchase orders (MEDRUCK) and indents, Delivery notes (RVDELNOTE), and Invoices (RVINVOICE) according to customer needs. • Modified existing layout sets for Purchase Order and GR using SAP Script. Data Migration:  https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN   • Implemented both Call Transaction and Session Method of BDC accordingly, depending upon the size, type, state and created routines for data upload using data extracts for sequential files on the application server and UPLOAD/WS_UPLOAD for local files on the presentation server. • Wrote ABAP programs for extracting data from SAP tables (Vendor master, Purchase Orders, Invoices and remittance) to be transferred to vendors using non-SAP systems for reconciliation and their local use. Object Oriented: • Created local and global classes with SE24 and within programs. • Used the Standard ALV classes in OOPs ALV reports. • Used ABSTRACT classes and Interfaces. • Having knowledge and used the different object oriented concepts technically.  SKILLS  SAP (2 years), ABAP (2 years), ADBC (Less than 1 year), C++ (Less than 1 year), DATA MODELING (Less than 1 year)  ADDITIONAL INFORMATION  OTHER TECHNICAL SKILLS • Trained on SAP S4 HANA. • Having knowledge of Code Push down, CDS view and it's consumption in ABAP. • Data Modeling, creation of different type of views. • AMDP. • ADBC connectivity. • Familiar with SQL, DDL, DML syntaxes. • Work on Windows 7, Windows XP, Windows 8, Windows 10 OS, can work on C, C++ ACADEMEIC CREDENTIALS 2015 Master of Computer Application UPTU. India|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
document = DocumentAssembler().setInputCol('text').setOutputCol('document').setCleanupMode('shrink')

# %%
sentence = SentenceDetector().setInputCols('document').setOutputCol('sentence')

# %%
sentence.setExplodeSentences(True)
# Out:
# SentenceDetector_b049295c6a93

# %% [markdown]
# ##### Tokenizing data

# %%
tokenizer = Tokenizer().setInputCols('sentence').setOutputCol('token')

# %%
tokenizer.setExceptions(['e-mail'])
# Out:
# Tokenizer_eedf2261a320

# %%
checker= NorvigSweetingModel.pretrained().setInputCols(['token']).setOutputCol('checked')
# Out:
# spellcheck_norvig download started this may take some time.
# Approximate size to download 4.2 MB
# [OK!]

# %% [markdown]
# ##### Embedding Data by WordEmbeddings method

# %%
embeddings=WordEmbeddingsModel.pretrained().setInputCols(['sentence','checked']).setOutputCol('embeddings')
# Out:
# glove_100d download started this may take some time.
# Approximate size to download 145.3 MB
# [OK!]

# %% [markdown]
# ##### NER

# %%
ner = NerDLModel.pretrained().setInputCols(['sentence','checked','embeddings']).setOutputCol('ner')
# Out:
# ner_dl download started this may take some time.
# Approximate size to download 13.6 MB
# [OK!]

# %%
converter = NerConverter().setInputCols(['sentence','checked','ner']).setOutputCol('chunk')

# %% [markdown]
# ##### Importing Pipeline Pakage from pyspark.ml

# %%
from pyspark.ml import Pipeline

# %% [markdown]
# ##### Creating Spark-NLP Pipeline

# %%
pipeline = Pipeline().setStages([document, sentence, tokenizer, checker, embeddings, ner, converter])

# %% [markdown]
# ##### Model Building

# %%
model = pipeline.fit(data2)

# %%
result = model.transform(data2)

# %% [markdown]
# ##### Outcome

# %%
result.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|             checked|          embeddings|                 ner|               chunk|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 0, 40...|[{token, 0, 5, Na...|[{token, 0, 5, Na...|[{word_embeddings...|[{named_entity, 0...|[{chunk, 0, 21, N...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 406, ...|[{token, 406, 414...|[{token, 406, 414...|[{word_embeddings...|[{named_entity, 4...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 506, ...|[{token, 506, 512...|[{token, 506, 512...|[{word_embeddings...|[{named_entity, 5...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 660, ...|[{token, 660, 666...|[{token, 660, 666...|[{word_embeddings...|[{named_entity, 6...|[{chunk, 724, 744...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 909, ...|[{token, 909, 909...|[{token, 909, 909...|[{word_embeddings...|[{named_entity, 9...|[{chunk, 980, 984...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1144,...|[{token, 1144, 11...|[{token, 1144, 11...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1161, 11...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1253,...|[{token, 1253, 12...|[{token, 1253, 12...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1341, 13...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1415,...|[{token, 1415, 14...|[{token, 1415, 14...|[{word_embeddings...|[{named_entity, 1...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1465,...|[{token, 1465, 14...|[{token, 1465, 14...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1465, 14...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1561,...|[{token, 1561, 15...|[{token, 1561, 15...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1591, 15...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1728,...|[{token, 1728, 17...|[{token, 1728, 17...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 1792, 17...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 1804,...|[{token, 1804, 18...|[{token, 1804, 18...|[{word_embeddings...|[{named_entity, 1...|[{chunk, 2050, 20...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2291,...|[{token, 2291, 22...|[{token, 2291, 22...|[{word_embeddings...|[{named_entity, 2...|[{chunk, 2299, 23...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2498,...|[{token, 2498, 25...|[{token, 2498, 25...|[{word_embeddings...|[{named_entity, 2...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2581,...|[{token, 2581, 25...|[{token, 2581, 25...|[{word_embeddings...|[{named_entity, 2...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2634,...|[{token, 2634, 26...|[{token, 2634, 26...|[{word_embeddings...|[{named_entity, 2...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2674,...|[{token, 2674, 26...|[{token, 2674, 26...|[{word_embeddings...|[{named_entity, 2...|                  []|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2754,...|[{token, 2754, 27...|[{token, 2754, 27...|[{word_embeddings...|[{named_entity, 2...|[{chunk, 2933, 29...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 2946,...|[{token, 2946, 29...|[{token, 2946, 29...|[{word_embeddings...|[{named_entity, 2...|[{chunk, 2968, 29...|
# |Nazish Alam Consu...|[{document, 0, 32...|[{document, 3023,...|[{token, 3023, 30...|[{token, 3023, 30...|[{word_embeddings...|[{named_entity, 3...|                  []|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
result.select('sentence.result').show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |result                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[Nazish Alam Consultant - SAP ABAP Ghaziabad, Uttar Pradesh - Email me on Indeed: indeed.com/r/Nazish-Alam/ b06dbac9d6236221 Willing to relocate to: Delhi, Delhi - Noida, Uttar Pradesh - Lucknow, Uttar Pradesh WORK EXPERIENCE Consultant SAP ABAP - Noida, Uttar Pradesh - November 2016 to Present Credence Systems, Noida Credence Systems is IT Infrastructure Management Company, offers end-to-end solutions.]                                                                                 |
# |[Combining deep domain expertise with new technologies and a cost effective on-site/ offshore model.]                                                                                                                                                                                                                                                                                                                                                                                                   |
# |[Helping companies integrate key business processes, improving their operational efficiencies and extracting, better business value from their investment.]                                                                                                                                                                                                                                                                                                                                             |
# |[PROJECT UNDERTAKEN Client ECC Version Role and Responsibilities Welspun Group Plate & Coil Mills Division SAP ECC 6.0 Consultant SAP ABAP - January 2016 to Present Reports: • Designed technical program specifications based on business requirements.]                                                                                                                                                                                                                                              |
# |[• Generated basic lists and Interactive Reports for information in the MM/SD including Sales, Billing, Purchasing, Goods Received, Inspection Plan, and Batch Determination using ABAP programs, Screen, Report Painter and Menu Painters.]                                                                                                                                                                                                                                                            |
# |[Used Parameters, Select-options and Match Codes to make the reports more friendly and intuitive to the user.]                                                                                                                                                                                                                                                                                                                                                                                          |
# |[• Generated different kind of reports like for PR (Purchase Requisition) analysis using ALV, PO (Purchase Order) Pricing details, Pending Export Sales order etc.]                                                                                                                                                                                                                                                                                                                                     |
# |[• Developed report for the daily production done.]                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |[SAP Scripts: • Generated various client specific Layout sets and form letters using SAP Script.]                                                                                                                                                                                                                                                                                                                                                                                                       |
# |[• Involved in modification of SAP scripts for Purchase orders (MEDRUCK) and indents, Delivery notes (RVDELNOTE), and Invoices (RVINVOICE) according to customer needs.]                                                                                                                                                                                                                                                                                                                                |
# |[• Modified existing layout sets for Purchase Order and GR using SAP Script.]                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |[Data Migration: https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN • Implemented both Call Transaction and Session Method of BDC accordingly, depending upon the size, type, state and created routines for data upload using data extracts for sequential files on the application server and UPLOAD/WS_UPLOAD for local files on the presentation server.]|
# |[• Wrote ABAP programs for extracting data from SAP tables (Vendor master, Purchase Orders, Invoices and remittance) to be transferred to vendors using non-SAP systems for reconciliation and their local use.]                                                                                                                                                                                                                                                                                        |
# |[Object Oriented: • Created local and global classes with SE24 and within programs.]                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |[• Used the Standard ALV classes in OOPs ALV reports.]                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |[• Used ABSTRACT classes and Interfaces.]                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |[• Having knowledge and used the different object oriented concepts technically.]                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |[SKILLS SAP (2 years), ABAP (2 years), ADBC (Less than 1 year), C++ (Less than 1 year), DATA MODELING (Less than 1 year) ADDITIONAL INFORMATION OTHER TECHNICAL SKILLS • Trained on SAP S4 HANA.]                                                                                                                                                                                                                                                                                                       |
# |[• Having knowledge of Code Push down, CDS view and it's consumption in ABAP.]                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |[• Data Modeling, creation of different type of views.]                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
result.select('checked.result').show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |result                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[Nazism, Alma, Consultant, -, SAP, ABA, Ghaziabad, ,, ottar, Pradesh, -, Email, me, on, Indeed, :, indeed.com/r/Nazish-Alam/, b06dbac9d6236221, Willing, to, relocate, to, :, Delhi, ,, Delhi, -, Needy, ,, attar, Pradesh, -, Lucknow, ,, attar, Pradesh, WORK, EXPERIENCE, Consultant, SAP, ABA, -, Needy, ,, attar, Pradesh, -, November, 2016, to, Present, credence, Systems, ,, Needy, credence, Systems, is, IT, Infrastructure, Management, Company, ,, offers, end-to-end, solutions, .]                                                              |
# |[Combining, deep, domain, expertise, with, new, technologies, and, a, cost, effective, on-site/, offshore, model, .]                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |[Helping, companies, integrate, key, business, processes, ,, improving, their, operational, efficiencies, and, extracting, ,, better, business, value, from, their, investment, .]                                                                                                                                                                                                                                                                                                                                                                             |
# |[PROJECT, UNDERTAKEN, Client, ECC, version, Role, and, Responsibilities, Welspun, Group, Plate, &, soil, Mills, Division, SAP, ECC, 6.0, Consultant, SAP, ABA, -, January, 2016, to, Present, Reports, :, •, Designed, technical, program, specifications, based, on, business, requirements, .]                                                                                                                                                                                                                                                               |
# |[•, generated, basic, lists, and, interactive, Reports, for, information, in, the, MM/SD, including, Sales, ,, willing, ,, purchasing, ,, Gods, received, ,, Inspection, Plan, ,, and, catch, Determination, using, ABA, programs, ,, Screen, ,, Report, Painter, and, Menu, painters, .]                                                                                                                                                                                                                                                                      |
# |[Used, parameters, ,, Select-options, and, Match, Codes, to, make, the, reports, more, friendly, and, intuitive, to, the, user, .]                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |[•, generated, different, kind, of, reports, like, for, PR, (, Purchase, requisition, ), analysis, using, ALV, ,, PO, (, Purchase, Order, ), Pricing, details, ,, Pending, Export, Sales, order, etc, .]                                                                                                                                                                                                                                                                                                                                                       |
# |[•, Developed, report, for, the, daily, production, done, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |[SAP, Scripts, :, •, generated, various, client, specific, payout, sets, and, form, letters, using, SAP, Script, .]                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |[•, Involved, in, modification, of, SAP, scripts, for, Purchase, orders, (, MEDRUCK, ), and, indents, ,, delivery, notes, (, RVDELNOTE, ),, and, invoices, (, RVINVOICE, ), according, to, customer, needs, .]                                                                                                                                                                                                                                                                                                                                                 |
# |[•, Modified, existing, layout, sets, for, Purchase, Order, and, GR, using, SAP, Script, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |[Data, Migration, :, https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN, https://www.indeed.com/r/Nazish-Alam/b06dbac9d6236221?isid=rex-download&ikw=download-top&co=IN, •, implemented, both, Call, transaction, and, Session, Method, of, BDC, accordingly, ,, depending, upon, the, size, ,, type, ,, state, and, created, routines, for, data, upload, using, data, extracts, for, sequential, files, on, the, application, server, and, UPLOAD/WS_UPLOAD, for, local, files, on, the, presentation, server, .]|
# |[•, wrote, ABA, programs, for, extracting, data, from, SAP, tables, (, vendor, master, ,, Purchase, Orders, ,, invoices, and, remittance, ), to, be, transferred, to, vendors, using, non-SAP, systems, for, reconciliation, and, their, local, use, .]                                                                                                                                                                                                                                                                                                        |
# |[Object, oriented, :, •, Created, local, and, global, classes, with, SE24, and, within, programs, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |[•, Used, the, Standard, ALV, classes, in, OOP, ALV, reports, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |[•, Used, ABSTRACT, classes, and, interfaces, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |[•, Having, knowledge, and, used, the, different, object, oriented, concepts, technically, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |[SKILLS, SAP, (, 2, years, ),, ABA, (, 2, years, ),, ADB, (, Less, than, 1, year, ),, C++, (, Less, than, 1, year, ),, DATA, MODELING, (, Less, than, 1, year, ), ADDITIONAL, INFORMATION, OTHER, TECHNICAL, SKILLS, •, trained, on, SAP, S4, HAA, .]                                                                                                                                                                                                                                                                                                          |
# |[•, Having, knowledge, of, Code, Push, down, ,, CDS, view, and, it's, consumption, in, ABA, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |[•, Data, modeling, ,, creation, of, different, type, of, views, .]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
result.select('ner.result').show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |result                                                                                                                                                                                                                                                                                               |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[B-ORG, I-ORG, I-ORG, O, B-ORG, I-ORG, I-ORG, O, O, B-LOC, O, O, O, O, O, O, O, O, O, O, O, O, O, B-LOC, O, B-LOC, O, O, O, B-ORG, I-ORG, O, B-ORG, O, O, B-LOC, O, O, O, B-ORG, I-ORG, O, O, O, I-ORG, I-ORG, O, O, O, O, O, O, B-ORG, I-ORG, I-ORG, O, O, O, O, I-ORG, I-ORG, I-ORG, O, O, O, O, O]|
# |[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                                        |
# |[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                      |
# |[O, O, O, O, O, O, O, O, B-ORG, I-ORG, I-ORG, I-ORG, O, O, O, B-ORG, I-ORG, O, B-ORG, I-ORG, I-ORG, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                               |
# |[O, O, O, O, O, O, O, O, O, O, O, B-ORG, O, O, O, O, O, O, O, B-PER, O, O, B-MISC, I-MISC, O, O, O, O, O, B-ORG, O, O, B-ORG, O, B-ORG, I-ORG, O, B-MISC, O, O]                                                                                                                                      |
# |[O, O, O, B-PER, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                        |
# |[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG, I-ORG, I-ORG, I-ORG, I-ORG, I-ORG, O, O, O, O, B-ORG, I-ORG, O, O, O, O]                                                                                                                                                                        |
# |[O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                                                          |
# |[B-ORG, I-ORG, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG, I-ORG, O]                                                                                                                                                                                                                                  |
# |[O, O, O, O, O, B-ORG, O, O, O, O, O, B-ORG, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG, O, O, O, O, O, O]                                                                                                                                                                                            |
# |[O, O, O, O, O, O, O, O, O, O, O, B-ORG, O, O]                                                                                                                                                                                                                                                       |
# |[O, O, O, O, O, O, O, O, O, O, O, B-ORG, I-ORG, I-ORG, I-ORG, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG, O, O, O, O, O, O, O, O]                                                                                                                        |
# |[O, O, B-ORG, O, O, O, O, O, B-ORG, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                 |
# |[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                                        |
# |[O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                                                    |
# |[O, O, O, O, O, O, O]                                                                                                                                                                                                                                                                                |
# |[O, O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                                                 |
# |[O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, B-ORG, O, O, O]                                                                                                                                                          |
# |[O, O, O, O, B-MISC, I-MISC, O, O, O, O, O, O, O, O, B-ORG, O]                                                                                                                                                                                                                                       |
# |[O, O, O, O, O, O, O, O, O, O, O]                                                                                                                                                                                                                                                                    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
result.select('ner.begin', 'ner.end').show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |begin                                                                                                                                                                                                                                                                                                                       |end                                                                                                                                                                                                                                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[0, 7, 12, 23, 25, 29, 34, 43, 45, 51, 59, 61, 67, 70, 73, 79, 81, 107, 124, 132, 135, 144, 146, 148, 153, 155, 161, 163, 168, 170, 176, 184, 186, 193, 195, 201, 209, 214, 225, 236, 240, 245, 247, 252, 254, 260, 268, 270, 279, 284, 287, 295, 304, 311, 313, 319, 328, 336, 339, 342, 357, 368, 375, 377, 384, 395, 404]|[5, 10, 21, 23, 27, 32, 42, 43, 49, 57, 59, 65, 68, 71, 78, 79, 105, 122, 130, 133, 142, 145, 146, 152, 153, 159, 161, 167, 168, 174, 182, 184, 192, 193, 199, 207, 212, 223, 234, 238, 243, 245, 251, 252, 258, 266, 268, 277, 282, 285, 293, 302, 310, 311, 317, 326, 334, 337, 340, 355, 366, 374, 375, 382, 393, 403, 404]|
# |[406, 416, 421, 428, 438, 443, 447, 460, 464, 466, 471, 481, 490, 499, 504]                                                                                                                                                                                                                                                 |[414, 419, 426, 436, 441, 445, 458, 462, 464, 469, 479, 488, 497, 503, 504]                                                                                                                                                                                                                                                   |
# |[506, 514, 524, 534, 538, 547, 556, 558, 568, 574, 586, 599, 603, 613, 615, 622, 631, 637, 642, 648, 658]                                                                                                                                                                                                                   |[512, 522, 532, 536, 545, 555, 556, 566, 572, 584, 597, 601, 612, 613, 620, 629, 635, 640, 646, 657, 658]                                                                                                                                                                                                                     |
# |[660, 668, 679, 686, 690, 698, 703, 707, 724, 732, 738, 744, 746, 751, 757, 766, 770, 774, 778, 789, 793, 798, 800, 808, 813, 816, 824, 831, 833, 835, 844, 854, 862, 877, 883, 886, 895, 907]                                                                                                                              |[666, 677, 684, 688, 696, 701, 705, 722, 730, 736, 742, 744, 749, 755, 764, 768, 772, 776, 787, 791, 796, 798, 806, 811, 814, 822, 830, 831, 833, 842, 852, 860, 875, 881, 884, 893, 906, 907]                                                                                                                                |
# |[909, 911, 921, 927, 933, 937, 949, 957, 961, 973, 976, 980, 986, 996, 1001, 1003, 1010, 1012, 1022, 1024, 1030, 1038, 1040, 1051, 1055, 1057, 1061, 1067, 1081, 1087, 1092, 1100, 1102, 1108, 1110, 1117, 1125, 1129, 1134, 1142]                                                                                          |[909, 919, 925, 931, 935, 947, 955, 959, 971, 974, 978, 984, 994, 1000, 1001, 1009, 1010, 1021, 1022, 1028, 1037, 1038, 1049, 1054, 1055, 1059, 1065, 1079, 1085, 1090, 1099, 1100, 1107, 1108, 1115, 1123, 1127, 1132, 1141, 1142]                                                                                           |
# |[1144, 1149, 1159, 1161, 1176, 1180, 1186, 1192, 1195, 1200, 1204, 1212, 1217, 1226, 1230, 1240, 1243, 1247, 1251]                                                                                                                                                                                                          |[1147, 1158, 1159, 1174, 1178, 1184, 1190, 1193, 1198, 1202, 1210, 1215, 1224, 1228, 1238, 1241, 1245, 1250, 1251]                                                                                                                                                                                                            |
# |[1253, 1255, 1265, 1275, 1280, 1283, 1291, 1296, 1300, 1303, 1304, 1313, 1324, 1326, 1335, 1341, 1344, 1346, 1349, 1350, 1359, 1364, 1366, 1374, 1381, 1383, 1391, 1398, 1404, 1410, 1413]                                                                                                                                  |[1253, 1263, 1273, 1278, 1281, 1289, 1294, 1298, 1301, 1303, 1311, 1323, 1324, 1333, 1339, 1343, 1344, 1347, 1349, 1357, 1363, 1364, 1372, 1380, 1381, 1389, 1396, 1402, 1408, 1412, 1413]                                                                                                                                    |
# |[1415, 1417, 1427, 1434, 1438, 1442, 1448, 1459, 1463]                                                                                                                                                                                                                                                                      |[1415, 1425, 1432, 1436, 1440, 1446, 1457, 1462, 1463]                                                                                                                                                                                                                                                                        |
# |[1465, 1469, 1476, 1478, 1480, 1490, 1498, 1505, 1514, 1521, 1526, 1530, 1535, 1543, 1549, 1553, 1559]                                                                                                                                                                                                                      |[1467, 1475, 1476, 1478, 1488, 1496, 1503, 1512, 1519, 1524, 1528, 1533, 1541, 1547, 1551, 1558, 1559]                                                                                                                                                                                                                        |
# |[1561, 1563, 1572, 1575, 1588, 1591, 1595, 1603, 1607, 1616, 1623, 1624, 1631, 1633, 1637, 1644, 1646, 1655, 1661, 1662, 1671, 1674, 1678, 1687, 1688, 1697, 1699, 1709, 1712, 1721, 1726]                                                                                                                                  |[1561, 1570, 1573, 1586, 1589, 1593, 1601, 1605, 1614, 1621, 1623, 1630, 1631, 1635, 1643, 1644, 1653, 1659, 1661, 1670, 1672, 1676, 1685, 1687, 1696, 1697, 1707, 1710, 1719, 1725, 1726]                                                                                                                                    |
# |[1728, 1730, 1739, 1748, 1755, 1760, 1764, 1773, 1779, 1783, 1786, 1792, 1796, 1802]                                                                                                                                                                                                                                        |[1728, 1737, 1746, 1753, 1758, 1762, 1771, 1777, 1781, 1784, 1790, 1794, 1801, 1802]                                                                                                                                                                                                                                          |
# |[1804, 1809, 1818, 1820, 1915, 2010, 2012, 2024, 2029, 2034, 2046, 2050, 2058, 2065, 2068, 2072, 2083, 2085, 2095, 2100, 2104, 2108, 2110, 2114, 2116, 2122, 2126, 2134, 2143, 2147, 2152, 2159, 2165, 2170, 2179, 2183, 2194, 2200, 2203, 2207, 2219, 2226, 2230, 2247, 2251, 2257, 2263, 2266, 2270, 2283, 2289]          |[1807, 1817, 1818, 1913, 2008, 2010, 2022, 2027, 2032, 2044, 2048, 2056, 2063, 2066, 2070, 2082, 2083, 2093, 2098, 2102, 2107, 2108, 2113, 2114, 2120, 2124, 2132, 2141, 2145, 2150, 2157, 2163, 2168, 2177, 2181, 2192, 2198, 2201, 2205, 2217, 2224, 2228, 2245, 2249, 2255, 2261, 2264, 2268, 2281, 2288, 2289]            |
# |[2291, 2293, 2299, 2304, 2313, 2317, 2328, 2333, 2338, 2342, 2349, 2350, 2357, 2363, 2365, 2374, 2380, 2382, 2391, 2395, 2405, 2407, 2410, 2413, 2425, 2428, 2436, 2442, 2450, 2458, 2462, 2477, 2481, 2487, 2493, 2496]                                                                                                    |[2291, 2297, 2302, 2311, 2315, 2326, 2331, 2336, 2340, 2347, 2349, 2355, 2362, 2363, 2372, 2379, 2380, 2389, 2393, 2404, 2405, 2408, 2411, 2423, 2426, 2434, 2440, 2448, 2456, 2460, 2475, 2479, 2485, 2491, 2495, 2496]                                                                                                      |
# |[2498, 2505, 2513, 2515, 2517, 2525, 2531, 2535, 2542, 2550, 2555, 2560, 2564, 2571, 2579]                                                                                                                                                                                                                                  |[2503, 2512, 2513, 2515, 2523, 2529, 2533, 2540, 2548, 2553, 2558, 2562, 2569, 2578, 2579]                                                                                                                                                                                                                                    |
# |[2581, 2583, 2588, 2592, 2601, 2605, 2613, 2616, 2621, 2625, 2632]                                                                                                                                                                                                                                                          |[2581, 2586, 2590, 2599, 2603, 2611, 2614, 2619, 2623, 2631, 2632]                                                                                                                                                                                                                                                            |
# |[2634, 2636, 2641, 2650, 2658, 2662, 2672]                                                                                                                                                                                                                                                                                  |[2634, 2639, 2648, 2656, 2660, 2671, 2672]                                                                                                                                                                                                                                                                                    |
# |[2674, 2676, 2683, 2693, 2697, 2702, 2706, 2716, 2723, 2732, 2741, 2752]                                                                                                                                                                                                                                                    |[2674, 2681, 2691, 2695, 2700, 2704, 2714, 2721, 2730, 2739, 2751, 2752]                                                                                                                                                                                                                                                      |
# |[2754, 2761, 2765, 2766, 2768, 2773, 2776, 2781, 2782, 2784, 2789, 2792, 2797, 2798, 2803, 2808, 2810, 2814, 2817, 2821, 2822, 2827, 2832, 2834, 2838, 2841, 2846, 2855, 2856, 2861, 2866, 2868, 2872, 2874, 2885, 2897, 2903, 2913, 2920, 2922, 2930, 2933, 2937, 2940, 2944]                                              |[2759, 2763, 2765, 2766, 2772, 2774, 2779, 2781, 2782, 2788, 2790, 2795, 2797, 2801, 2806, 2808, 2813, 2815, 2819, 2821, 2825, 2830, 2832, 2837, 2839, 2844, 2853, 2855, 2859, 2864, 2866, 2871, 2872, 2883, 2895, 2901, 2911, 2918, 2920, 2928, 2931, 2935, 2938, 2943, 2944]                                                |
# |[2946, 2948, 2955, 2965, 2968, 2973, 2978, 2982, 2984, 2988, 2993, 2997, 3002, 3014, 3017, 3021]                                                                                                                                                                                                                            |[2946, 2953, 2963, 2966, 2971, 2976, 2981, 2982, 2986, 2991, 2995, 3000, 3012, 3015, 3020, 3021]                                                                                                                                                                                                                              |
# |[3023, 3025, 3030, 3038, 3040, 3049, 3052, 3062, 3067, 3070, 3075]                                                                                                                                                                                                                                                          |[3023, 3028, 3037, 3038, 3047, 3050, 3060, 3065, 3068, 3074, 3075]                                                                                                                                                                                                                                                            |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
result.select('chunk.result','chunk.begin', 'chunk.end').show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------+---------------------------------------------------------+
# |result                                                                                                                                                                          |begin                                                   |end                                                      |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------+---------------------------------------------------------+
# |[Nazish Alam Consultant, SAP ABAP Ghaziabad, Uttar Pradesh, Delhi, Delhi, Pradesh, Lucknow, Pradesh, SAP ABAP, Uttar Pradesh, Systems, Noida, Infrastructure Management Company]|[0, 25, 45, 148, 155, 176, 186, 201, 236, 254, 304, 342]|[21, 42, 57, 152, 159, 182, 192, 207, 243, 266, 317, 374]|
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[Welspun Group Plate &, SAP ECC, Consultant SAP ABAP]                                                                                                                           |[724, 766, 778]                                         |[744, 772, 796]                                          |
# |[MM/SD, Goods, Inspection Plan, ABAP, Screen, Report Painter, Menu]                                                                                                             |[980, 1024, 1040, 1087, 1102, 1110, 1129]               |[984, 1028, 1054, 1090, 1107, 1123, 1132]                |
# |[Select-options]                                                                                                                                                                |[1161]                                                  |[1174]                                                   |
# |[ALV, PO (Purchase Order, Pending Export]                                                                                                                                       |[1341, 1383]                                            |[1363, 1396]                                             |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[SAP Scripts, SAP Script]                                                                                                                                                       |[1465, 1549]                                            |[1475, 1558]                                             |
# |[SAP, MEDRUCK, RVINVOICE]                                                                                                                                                       |[1591, 1624, 1688]                                      |[1593, 1630, 1696]                                       |
# |[SAP]                                                                                                                                                                           |[1792]                                                  |[1794]                                                   |
# |[Session Method of BDC, UPLOAD/WS_UPLOAD]                                                                                                                                       |[2050, 2230]                                            |[2070, 2245]                                             |
# |[ABAP, SAP]                                                                                                                                                                     |[2299, 2338]                                            |[2302, 2340]                                             |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# |[SAP]                                                                                                                                                                           |[2933]                                                  |[2935]                                                   |
# |[Code Push, ABAP]                                                                                                                                                               |[2968, 3017]                                            |[2976, 3020]                                             |
# |[]                                                                                                                                                                              |[]                                                      |[]                                                       |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------+---------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ##### Sample testing

# %%
Light=LightPipeline(model)

# %%
Light.annotate(data[2][0])
# Out:
# {'checked': ['Nitin',
#   'Tr',
#   'PeopleSoft',
#   'Consultant',
#   'Bangalore',
#   'Urban',
#   ',',
#   'Karnataka',
#   '-',
#   'Email',
#   'me',
#   'on',
#   'Indeed',
#   ':',
#   'indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e',
#   'An',
#   'ecommerce',
#   'website',
#   'I',
#   'built',
#   'as',
#   'my',
#   'college',
#   'project',
#   '.',
#   'The',
#   'website',
#   'contains',
#   'all',
#   'the',
#   'basic',
#   'elements',
#   'of',
#   'an',
#   'ecommerce',
#   'website',
#   'which',
#   'are',
#   'The',
#   'landing',
#   'page',
#   ',',
#   'categorization',
#   'of',
#   'items',
#   'based',
#   'on',
#   'filters',
#   ',',
#   'basic',
#   'session',
#   'level',
#   'security',
#   ',',
#   'product',
#   'page',
#   ',',
#   'part',
#   ',',
#   'share',
#   'button',
#   ',',
#   'empty',
#   'cart',
#   'button',
#   ',',
#   'pagination',
#   'etc',
#   '.',
#   'It',
#   'consists',
#   'of',
#   'a',
#   'separate',
#   'seller',
#   'accounts',
#   'where',
#   'sellers',
#   'can',
#   'register',
#   'and',
#   'later',
#   'upload',
#   'their',
#   'products',
#   'to',
#   'be',
#   'sold',
#   ',',
#   'which',
#   'can',
#   'later',
#   'be',
#   'edited',
#   'or',
#   'deleted',
#   '.',
#   'It',
#   'consists',
#   'of',
#   'an',
#   'admin',
#   'panel',
#   'where',
#   'all',
#   'the',
#   'products',
#   'listed',
#   'can',
#   'be',
#   'viewed',
#   'and',
#   'edited',
#   'by',
#   'the',
#   'moderator',
#   '.',
#   '60',
#   'days',
#   'auto',
#   'delete',
#   'feature',
#   ',',
#   'which',
#   'deletes',
#   'the',
#   'product',
#   'listing',
#   '60',
#   'days',
#   'from',
#   'the',
#   'date',
#   'of',
#   'upload',
#   'if',
#   'seller',
#   'has',
#   'not',
#   'modified',
#   'the',
#   'listing',
#   'upon',
#   'the',
#   'next',
#   'login',
#   '.',
#   'usage',
#   'of',
#   'Models',
#   'for',
#   'registration',
#   'and',
#   'Logan',
#   'which',
#   'reduces',
#   'the',
#   'number',
#   'of',
#   'pages',
#   'to',
#   'navigate',
#   '.',
#   'Languages',
#   'used',
#   ':',
#   'PHP',
#   ',',
#   'MySQL',
#   ',',
#   'Html',
#   ',',
#   'CSS',
#   ',',
#   'bootstrap',
#   ',',
#   'JavaScript',
#   'and',
#   'jQuery',
#   '.',
#   'WORK',
#   'EXPERIENCE',
#   'PeopleSoft',
#   'consultant',
#   'Oracle',
#   '-',
#   'September',
#   '2017',
#   'to',
#   'Present',
#   'Performing',
#   'customizations',
#   ',',
#   'enhancements',
#   'and',
#   'bug',
#   'fixes',
#   'for',
#   'front',
#   'end',
#   'and',
#   'backend',
#   'impeople',
#   'code',
#   'using',
#   'appdesigner',
#   '.',
#   'PeopleSoft',
#   'Consultant',
#   'Oracle',
#   'India',
#   'Ltd',
#   '-',
#   'September',
#   '2017',
#   'to',
#   'April',
#   '2018',
#   '•',
#   'Develop',
#   'customizations',
#   'to',
#   'meet',
#   'business',
#   'process',
#   'requirements',
#   'using',
#   'application',
#   'designer',
#   '.',
#   '•',
#   'Involved',
#   'in',
#   'modification',
#   'enhancement',
#   'and',
#   'bug-fixing',
#   'of',
#   'the',
#   'PeopleSoft',
#   'application',
#   'both',
#   'front',
#   '-',
#   'end',
#   'and',
#   'back-end',
#   'to',
#   'suit',
#   'business',
#   'needs',
#   '.',
#   '•',
#   'communicate',
#   'with',
#   'the',
#   'business',
#   'and',
#   'get',
#   'clear',
#   'requirements',
#   'if',
#   'adequate',
#   'information',
#   'is',
#   'not',
#   'available',
#   'and',
#   'also',
#   'follow-up',
#   'with',
#   'them',
#   'until',
#   'final',
#   'resolution',
#   'is',
#   'obtained',
#   '.',
#   '•',
#   'Release',
#   'enhancements',
#   'for',
#   'UAT',
#   'and',
#   'communicate',
#   'with',
#   'business',
#   'to',
#   'migrate',
#   'into',
#   'production',
#   '.',
#   'https://www.indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e?isid=rex-download&ikw=download-top&co=IN',
#   '•',
#   'Also',
#   'have',
#   'to',
#   'work',
#   'on',
#   'service',
#   'requests',
#   ',',
#   'Incident',
#   'Creation',
#   ',',
#   'Incident',
#   'Assignment',
#   'additionally',
#   'and',
#   'constantly',
#   'involved',
#   'in',
#   'querying',
#   'the',
#   'database',
#   'and',
#   'running',
#   'reports',
#   '.',
#   'freelance',
#   'Development',
#   'I',
#   'am',
#   'a',
#   'passionate',
#   'Web',
#   'Developer',
#   'and',
#   'love',
#   'to',
#   'build',
#   'clean',
#   ',',
#   'smooth',
#   'and',
#   'responsive',
#   'websites',
#   '.',
#   'I',
#   'have',
#   'built',
#   'many',
#   'websites',
#   'for',
#   'individuals',
#   'on',
#   'freelance',
#   'or',
#   'per-project',
#   'basis',
#   'which',
#   'are',
#   'responsive',
#   'in',
#   'nature',
#   '.',
#   'I',
#   'am',
#   'capable',
#   'of',
#   'building',
#   'clean',
#   'and',
#   'responsive',
#   'websites',
#   '.',
#   'They',
#   'include',
#   'personal',
#   'portfolios',
#   'and',
#   'Small',
#   'business',
#   'websites',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/shop',
#   ':',
#   'responsive',
#   'and',
#   'Dynamic',
#   'ecommerce',
#   'portal',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/tickItBusDemoUrl',
#   ':',
#   'A',
#   'bus',
#   'booking',
#   'platform',
#   ',',
#   'source',
#   ':',
#   'Kathmandu',
#   ',',
#   'destination',
#   ':',
#   'Pokhra',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/geisle/index.php',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   'focused',
#   'on',
#   'animations',
#   '(',
#   'under',
#   'construction',
#   ')',
#   'also',
#   'check',
#   '(',
#   'geisle/index2.php',
#   ')',
#   '•',
#   'http://pramodprakash.com/fulllogin',
#   ':',
#   'complete',
#   'login',
#   'module',
#   'with',
#   'email',
#   'account',
#   'activation',
#   'and',
#   'password',
#   'reset',
#   '.',
#   '•',
#   'http://pramodprakash.com/sec',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   ',',
#   'built',
#   'to',
#   'showcase',
#   'color',
#   'combinations',
#   'and',
#   'layout',
#   '.',
#   '•',
#   'http://pramodprakash.com/r&d',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   'built',
#   'in',
#   'parallax',
#   'format',
#   '.',
#   'Completely',
#   'responsive',
#   '.',
#   '•',
#   'http://pramodprakash.com/web1',
#   ':',
#   'A',
#   'template',
#   'built',
#   'according',
#   'to',
#   'given',
#   'specifications',
#   'and',
#   'also',
#   'small',
#   'map',
#   'feature',
#   'included',
#   'which',
#   'also',
#   'supports',
#   'location',
#   'search',
#   '.',
#   'EDUCATION',
#   'Beech',
#   'information',
#   'science',
#   'in',
#   'BCE',
#   'Vtu',
#   '-',
#   'Bengaluru',
#   ',',
#   'Karnataka',
#   '2017',
#   'Vijay',
#   'composite',
#   'p.u',
#   '.',
#   'college',
#   'ecommerce',
#   'Vijay',
#   'High',
#   'School',
#   'SKILLS',
#   'Php',
#   ',',
#   'Html5',
#   ',',
#   'Javascript',
#   ',',
#   'Css',
#   ',',
#   'bootstrap',
#   ',',
#   'query',
#   ',',
#   'Sql',
#   'LINKS',
#   'https://www.linkedin.com/in/nitin-tr-588105129',
#   'ADDITIONAL',
#   'INFORMATION',
#   'Software',
#   'Skills',
#   'https://www.linkedin.com/in/nitin-tr-588105129',
#   '•',
#   'Programming',
#   'Language',
#   ':',
#   'core',
#   'lava',
#   ',',
#   'peoplecode',
#   '.',
#   '•',
#   'scripting',
#   'languages',
#   ':',
#   'PHP',
#   ',',
#   'JavaScript',
#   '.',
#   '•',
#   'Web',
#   'Languages',
#   ':',
#   'HTML',
#   ',',
#   'CSS',
#   '.',
#   '•',
#   'Database',
#   'Language',
#   ':',
#   'Sql',
#   '.',
#   '•',
#   'frameworks',
#   ':',
#   'bootstrap',
#   ',',
#   'JQuery',
#   '.',
#   '•',
#   "IDE's",
#   ':',
#   'NetBeans',
#   ',',
#   'Eclipse',
#   '.',
#   '•',
#   'Tools',
#   ':',
#   'Application',
#   'Designer',
#   ',',
#   'Toad',
#   '.',
#   'Personal',
#   'Skills',
#   '•',
#   'Excellent',
#   'Communication',
#   'Skills',
#   'both',
#   'Written',
#   'and',
#   'verbal',
#   '.',
#   '•',
#   'Honest',
#   ',',
#   'trustworthy',
#   'and',
#   'highly',
#   'motivated',
#   'team',
#   'player',
#   'and',
#   'Strong',
#   'Negotiator',
#   '.',
#   '•',
#   'supportive',
#   'and',
#   'creative',
#   '.',
#   '•',
#   'Quick',
#   'Learn',
#   'and',
#   'flexible',
#   '.',
#   '•',
#   'Good',
#   'Analytical',
#   'Ability',
#   'and',
#   'logical',
#   'Reasoning',
#   '.',
#   '•',
#   'Good',
#   'listening',
#   'skills',
#   '.'],
#  'chunk': ['PeopleSoft Consultant Bangalore Urban',
#   'Karnataka',
#   'Login',
#   'Languages',
#   'PHP',
#   'MySQL',
#   'Html',
#   'CSS',
#   'JavaScript',
#   'PeopleSoft',
#   'Oracle',
#   'PeopleSoft Consultant Oracle India Ltd',
#   '• Develop',
#   'PeopleSoft',
#   'UAT',
#   '• Also',
#   'Incident Creation, Incident Assignment',
#   'Web Developer',
#   'Kathmandu',
#   'Pokhra',
#   'EDUCATION Btech',
#   'BCET Vtu',
#   'Bengaluru',
#   'Karnataka',
#   'Vijaya',
#   'Vijaya High School',
#   'Javascript',
#   'Css',
#   'Sql LINKS',
#   'ADDITIONAL INFORMATION Software Skills',
#   'Language',
#   'PHP',
#   'JavaScript',
#   'Languages',
#   'CSS',
#   'Language',
#   'JQuery',
#   'NetBeans',
#   'Toad',
#   '• Excellent Communication Skills',
#   '• Honest',
#   '• Good Analytical Ability'],
#  'document': ["Nitin Tr PeopleSoft Consultant Bangalore Urban, Karnataka - Email me on Indeed: indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e An e-commerce website I built as my college project. The website contains all the basic elements of an e-commerce website which are The landing page, categorization of items based on filters, basic session level security, product page, Cart, share button, empty cart button, paginations etc. It consists of a separate seller accounts where sellers can register and later upload their products to be sold, which can later be edited or deleted. It consists of an admin panel where all the products listed can be viewed and edited by the moderator. 60 days auto delete feature, which deletes the product listing 60 days from the date of upload if seller has not modified the listing upon the next login. Usage of Modals for registration and Login which reduces the number of pages to navigate. Languages used: PHP, MySQL, Html, CSS, Bootstrap, JavaScript and jQuery. WORK EXPERIENCE PeopleSoft consultant Oracle - September 2017 to Present Performing customisations, enhancements and bug fixes for front end and backend inpeople code using appdesigner. PeopleSoft Consultant Oracle India Ltd - September 2017 to April 2018 • Develop customizations to meet business process requirements using application designer. • Involved in modification enhancement and bug-fixing of the PeopleSoft application both front- end and back-end to suit business needs. • Communicate with the business and get clear requirements if adequate information is not available and also follow-up with them until final resolution is obtained. • Release Enhancements for UAT and communicate with business to migrate into production. https://www.indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e?isid=rex-download&ikw=download-top&co=IN • Also have to work on service requests, Incident Creation, Incident Assignment additionally and constantly involved in querying the database and running reports. Freelance Development I am a passionate Web Developer and love to build clean, smooth and responsive websites. I have built many websites for individuals on freelance or per-project basis which are Responsive in nature. I am capable of building clean and responsive websites. They include personal portfolios and Small business websites. • http://www.pramodprakash.com/shop: Responsive and Dynamic e-commerce portal. • http://www.pramodprakash.com/tickItBusDemoUrl: A bus booking platform, source: Kathmandu, Destination: Pokhra. • http://www.pramodprakash.com/geisle/index.php: A small business website focused on animations (under construction) also check (geisle/index2.php) • http://pramodprakash.com/fulllogin: complete login module with email account activation and password reset. • http://pramodprakash.com/sec: A small business website, built to showcase color combinations and layout. • http://pramodprakash.com/r&d: A small business website built in parallax format. Completely responsive. • http://pramodprakash.com/web1: A template built according to given specifications and also small map feature included which also supports location search. EDUCATION Btech information science in BCET Vtu - Bengaluru, Karnataka 2017 Vijaya composite p.u. college e-commerce Vijaya High School SKILLS Php, Html5, Javascript, Css, Bootstrap, Jquery, Sql LINKS https://www.linkedin.com/in/nitin-tr-588105129 ADDITIONAL INFORMATION Software Skills https://www.linkedin.com/in/nitin-tr-588105129 • Programming Language: core java, peoplecode. • Scripting languages: PHP, JavaScript. • Web Languages: HTML, CSS. • Database Language: Sql. • Frameworks: Bootstrap, JQuery. • IDE's: NetBeans, Eclipse. • Tools: Application Designer, Toad. Personal Skills • Excellent Communication Skills both Written and verbal. • Honest, trustworthy and highly motivated team player and Strong Negotiator. • Supportive and creative. • Quick Learner and Flexible. • Good Analytical Ability and Logical Reasoning. • Good listening ski ...
#  'embeddings': ['Nitin',
#   'Tr',
#   'PeopleSoft',
#   'Consultant',
#   'Bangalore',
#   'Urban',
#   ',',
#   'Karnataka',
#   '-',
#   'Email',
#   'me',
#   'on',
#   'Indeed',
#   ':',
#   'indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e',
#   'An',
#   'ecommerce',
#   'website',
#   'I',
#   'built',
#   'as',
#   'my',
#   'college',
#   'project',
#   '.',
#   'The',
#   'website',
#   'contains',
#   'all',
#   'the',
#   'basic',
#   'elements',
#   'of',
#   'an',
#   'ecommerce',
#   'website',
#   'which',
#   'are',
#   'The',
#   'landing',
#   'page',
#   ',',
#   'categorization',
#   'of',
#   'items',
#   'based',
#   'on',
#   'filters',
#   ',',
#   'basic',
#   'session',
#   'level',
#   'security',
#   ',',
#   'product',
#   'page',
#   ',',
#   'part',
#   ',',
#   'share',
#   'button',
#   ',',
#   'empty',
#   'cart',
#   'button',
#   ',',
#   'pagination',
#   'etc',
#   '.',
#   'It',
#   'consists',
#   'of',
#   'a',
#   'separate',
#   'seller',
#   'accounts',
#   'where',
#   'sellers',
#   'can',
#   'register',
#   'and',
#   'later',
#   'upload',
#   'their',
#   'products',
#   'to',
#   'be',
#   'sold',
#   ',',
#   'which',
#   'can',
#   'later',
#   'be',
#   'edited',
#   'or',
#   'deleted',
#   '.',
#   'It',
#   'consists',
#   'of',
#   'an',
#   'admin',
#   'panel',
#   'where',
#   'all',
#   'the',
#   'products',
#   'listed',
#   'can',
#   'be',
#   'viewed',
#   'and',
#   'edited',
#   'by',
#   'the',
#   'moderator',
#   '.',
#   '60',
#   'days',
#   'auto',
#   'delete',
#   'feature',
#   ',',
#   'which',
#   'deletes',
#   'the',
#   'product',
#   'listing',
#   '60',
#   'days',
#   'from',
#   'the',
#   'date',
#   'of',
#   'upload',
#   'if',
#   'seller',
#   'has',
#   'not',
#   'modified',
#   'the',
#   'listing',
#   'upon',
#   'the',
#   'next',
#   'login',
#   '.',
#   'usage',
#   'of',
#   'Models',
#   'for',
#   'registration',
#   'and',
#   'Logan',
#   'which',
#   'reduces',
#   'the',
#   'number',
#   'of',
#   'pages',
#   'to',
#   'navigate',
#   '.',
#   'Languages',
#   'used',
#   ':',
#   'PHP',
#   ',',
#   'MySQL',
#   ',',
#   'Html',
#   ',',
#   'CSS',
#   ',',
#   'bootstrap',
#   ',',
#   'JavaScript',
#   'and',
#   'jQuery',
#   '.',
#   'WORK',
#   'EXPERIENCE',
#   'PeopleSoft',
#   'consultant',
#   'Oracle',
#   '-',
#   'September',
#   '2017',
#   'to',
#   'Present',
#   'Performing',
#   'customizations',
#   ',',
#   'enhancements',
#   'and',
#   'bug',
#   'fixes',
#   'for',
#   'front',
#   'end',
#   'and',
#   'backend',
#   'impeople',
#   'code',
#   'using',
#   'appdesigner',
#   '.',
#   'PeopleSoft',
#   'Consultant',
#   'Oracle',
#   'India',
#   'Ltd',
#   '-',
#   'September',
#   '2017',
#   'to',
#   'April',
#   '2018',
#   '•',
#   'Develop',
#   'customizations',
#   'to',
#   'meet',
#   'business',
#   'process',
#   'requirements',
#   'using',
#   'application',
#   'designer',
#   '.',
#   '•',
#   'Involved',
#   'in',
#   'modification',
#   'enhancement',
#   'and',
#   'bug-fixing',
#   'of',
#   'the',
#   'PeopleSoft',
#   'application',
#   'both',
#   'front',
#   '-',
#   'end',
#   'and',
#   'back-end',
#   'to',
#   'suit',
#   'business',
#   'needs',
#   '.',
#   '•',
#   'communicate',
#   'with',
#   'the',
#   'business',
#   'and',
#   'get',
#   'clear',
#   'requirements',
#   'if',
#   'adequate',
#   'information',
#   'is',
#   'not',
#   'available',
#   'and',
#   'also',
#   'follow-up',
#   'with',
#   'them',
#   'until',
#   'final',
#   'resolution',
#   'is',
#   'obtained',
#   '.',
#   '•',
#   'Release',
#   'enhancements',
#   'for',
#   'UAT',
#   'and',
#   'communicate',
#   'with',
#   'business',
#   'to',
#   'migrate',
#   'into',
#   'production',
#   '.',
#   'https://www.indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e?isid=rex-download&ikw=download-top&co=IN',
#   '•',
#   'Also',
#   'have',
#   'to',
#   'work',
#   'on',
#   'service',
#   'requests',
#   ',',
#   'Incident',
#   'Creation',
#   ',',
#   'Incident',
#   'Assignment',
#   'additionally',
#   'and',
#   'constantly',
#   'involved',
#   'in',
#   'querying',
#   'the',
#   'database',
#   'and',
#   'running',
#   'reports',
#   '.',
#   'freelance',
#   'Development',
#   'I',
#   'am',
#   'a',
#   'passionate',
#   'Web',
#   'Developer',
#   'and',
#   'love',
#   'to',
#   'build',
#   'clean',
#   ',',
#   'smooth',
#   'and',
#   'responsive',
#   'websites',
#   '.',
#   'I',
#   'have',
#   'built',
#   'many',
#   'websites',
#   'for',
#   'individuals',
#   'on',
#   'freelance',
#   'or',
#   'per-project',
#   'basis',
#   'which',
#   'are',
#   'responsive',
#   'in',
#   'nature',
#   '.',
#   'I',
#   'am',
#   'capable',
#   'of',
#   'building',
#   'clean',
#   'and',
#   'responsive',
#   'websites',
#   '.',
#   'They',
#   'include',
#   'personal',
#   'portfolios',
#   'and',
#   'Small',
#   'business',
#   'websites',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/shop',
#   ':',
#   'responsive',
#   'and',
#   'Dynamic',
#   'ecommerce',
#   'portal',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/tickItBusDemoUrl',
#   ':',
#   'A',
#   'bus',
#   'booking',
#   'platform',
#   ',',
#   'source',
#   ':',
#   'Kathmandu',
#   ',',
#   'destination',
#   ':',
#   'Pokhra',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/geisle/index.php',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   'focused',
#   'on',
#   'animations',
#   '(',
#   'under',
#   'construction',
#   ')',
#   'also',
#   'check',
#   '(',
#   'geisle/index2.php',
#   ')',
#   '•',
#   'http://pramodprakash.com/fulllogin',
#   ':',
#   'complete',
#   'login',
#   'module',
#   'with',
#   'email',
#   'account',
#   'activation',
#   'and',
#   'password',
#   'reset',
#   '.',
#   '•',
#   'http://pramodprakash.com/sec',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   ',',
#   'built',
#   'to',
#   'showcase',
#   'color',
#   'combinations',
#   'and',
#   'layout',
#   '.',
#   '•',
#   'http://pramodprakash.com/r&d',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   'built',
#   'in',
#   'parallax',
#   'format',
#   '.',
#   'Completely',
#   'responsive',
#   '.',
#   '•',
#   'http://pramodprakash.com/web1',
#   ':',
#   'A',
#   'template',
#   'built',
#   'according',
#   'to',
#   'given',
#   'specifications',
#   'and',
#   'also',
#   'small',
#   'map',
#   'feature',
#   'included',
#   'which',
#   'also',
#   'supports',
#   'location',
#   'search',
#   '.',
#   'EDUCATION',
#   'Beech',
#   'information',
#   'science',
#   'in',
#   'BCE',
#   'Vtu',
#   '-',
#   'Bengaluru',
#   ',',
#   'Karnataka',
#   '2017',
#   'Vijay',
#   'composite',
#   'p.u',
#   '.',
#   'college',
#   'ecommerce',
#   'Vijay',
#   'High',
#   'School',
#   'SKILLS',
#   'Php',
#   ',',
#   'Html5',
#   ',',
#   'Javascript',
#   ',',
#   'Css',
#   ',',
#   'bootstrap',
#   ',',
#   'query',
#   ',',
#   'Sql',
#   'LINKS',
#   'https://www.linkedin.com/in/nitin-tr-588105129',
#   'ADDITIONAL',
#   'INFORMATION',
#   'Software',
#   'Skills',
#   'https://www.linkedin.com/in/nitin-tr-588105129',
#   '•',
#   'Programming',
#   'Language',
#   ':',
#   'core',
#   'lava',
#   ',',
#   'peoplecode',
#   '.',
#   '•',
#   'scripting',
#   'languages',
#   ':',
#   'PHP',
#   ',',
#   'JavaScript',
#   '.',
#   '•',
#   'Web',
#   'Languages',
#   ':',
#   'HTML',
#   ',',
#   'CSS',
#   '.',
#   '•',
#   'Database',
#   'Language',
#   ':',
#   'Sql',
#   '.',
#   '•',
#   'frameworks',
#   ':',
#   'bootstrap',
#   ',',
#   'JQuery',
#   '.',
#   '•',
#   "IDE's",
#   ':',
#   'NetBeans',
#   ',',
#   'Eclipse',
#   '.',
#   '•',
#   'Tools',
#   ':',
#   'Application',
#   'Designer',
#   ',',
#   'Toad',
#   '.',
#   'Personal',
#   'Skills',
#   '•',
#   'Excellent',
#   'Communication',
#   'Skills',
#   'both',
#   'Written',
#   'and',
#   'verbal',
#   '.',
#   '•',
#   'Honest',
#   ',',
#   'trustworthy',
#   'and',
#   'highly',
#   'motivated',
#   'team',
#   'player',
#   'and',
#   'Strong',
#   'Negotiator',
#   '.',
#   '•',
#   'supportive',
#   'and',
#   'creative',
#   '.',
#   '•',
#   'Quick',
#   'Learn',
#   'and',
#   'flexible',
#   '.',
#   '•',
#   'Good',
#   'Analytical',
#   'Ability',
#   'and',
#   'logical',
#   'Reasoning',
#   '.',
#   '•',
#   'Good',
#   'listening',
#   'skills',
#   '.'],
#  'ner': ['O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  'sentence': ['Nitin Tr PeopleSoft Consultant Bangalore Urban, Karnataka - Email me on Indeed: indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e An e-commerce website I built as my college project.',
#   'The website contains all the basic elements of an e-commerce website which are The landing page, categorization of items based on filters, basic session level security, product page, Cart, share button, empty cart button, paginations etc.',
#   'It consists of a separate seller accounts where sellers can register and later upload their products to be sold, which can later be edited or deleted.',
#   'It consists of an admin panel where all the products listed can be viewed and edited by the moderator.',
#   '60 days auto delete feature, which deletes the product listing 60 days from the date of upload if seller has not modified the listing upon the next login.',
#   'Usage of Modals for registration and Login which reduces the number of pages to navigate.',
#   'Languages used: PHP, MySQL, Html, CSS, Bootstrap, JavaScript and jQuery.',
#   'WORK EXPERIENCE PeopleSoft consultant Oracle - September 2017 to Present Performing customisations, enhancements and bug fixes for front end and backend inpeople code using appdesigner.',
#   'PeopleSoft Consultant Oracle India Ltd - September 2017 to April 2018 • Develop customizations to meet business process requirements using application designer.',
#   '• Involved in modification enhancement and bug-fixing of the PeopleSoft application both front- end and back-end to suit business needs.',
#   '• Communicate with the business and get clear requirements if adequate information is not available and also follow-up with them until final resolution is obtained.',
#   '• Release Enhancements for UAT and communicate with business to migrate into production.',
#   'https://www.indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e?isid=rex-download&ikw=download-top&co=IN • Also have to work on service requests, Incident Creation, Incident Assignment additionally and constantly involved in querying the database and running reports.',
#   'Freelance Development I am a passionate Web Developer and love to build clean, smooth and responsive websites.',
#   'I have built many websites for individuals on freelance or per-project basis which are Responsive in nature.',
#   'I am capable of building clean and responsive websites.',
#   'They include personal portfolios and Small business websites.',
#   '• http://www.pramodprakash.com/shop: Responsive and Dynamic e-commerce portal.',
#   '• http://www.pramodprakash.com/tickItBusDemoUrl: A bus booking platform, source: Kathmandu, Destination: Pokhra.',
#   '• http://www.pramodprakash.com/geisle/index.php: A small business website focused on animations (under construction) also check (geisle/index2.php) • http://pramodprakash.com/fulllogin: complete login module with email account activation and password reset.',
#   '• http://pramodprakash.com/sec: A small business website, built to showcase color combinations and layout.',
#   '• http://pramodprakash.com/r&d: A small business website built in parallax format.',
#   'Completely responsive.',
#   '• http://pramodprakash.com/web1: A template built according to given specifications and also small map feature included which also supports location search.',
#   'EDUCATION Btech information science in BCET Vtu - Bengaluru, Karnataka 2017 Vijaya composite p.u. college e-commerce Vijaya High School SKILLS Php, Html5, Javascript, Css, Bootstrap, Jquery, Sql LINKS https://www.linkedin.com/in/nitin-tr-588105129 ADDITIONAL INFORMATION Software Skills https://www.linkedin.com/in/nitin-tr-588105129 • Programming Language: core java, peoplecode.',
#   '• Scripting languages: PHP, JavaScript.',
#   '• Web Languages: HTML, CSS.',
#   '• Database Language: Sql.',
#   '• Frameworks: Bootstrap, JQuery.',
#   "• IDE's: NetBeans, Eclipse.",
#   '• Tools: Application Designer, Toad.',
#   'Personal Skills • Excellent Communication Skills both Written and verbal.',
#   '• Honest, trustworthy and highly motivated team player and Strong Negotiator.',
#   '• Supportive and creative.',
#   '• Quick Learner and Flexible.',
#   '• Good Analytical Ability and Logical Reasoning.',
#   '• Good listening skills.'],
#  'token': ['Nitin',
#   'Tr',
#   'PeopleSoft',
#   'Consultant',
#   'Bangalore',
#   'Urban',
#   ',',
#   'Karnataka',
#   '-',
#   'Email',
#   'me',
#   'on',
#   'Indeed',
#   ':',
#   'indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e',
#   'An',
#   'e-commerce',
#   'website',
#   'I',
#   'built',
#   'as',
#   'my',
#   'college',
#   'project',
#   '.',
#   'The',
#   'website',
#   'contains',
#   'all',
#   'the',
#   'basic',
#   'elements',
#   'of',
#   'an',
#   'e-commerce',
#   'website',
#   'which',
#   'are',
#   'The',
#   'landing',
#   'page',
#   ',',
#   'categorization',
#   'of',
#   'items',
#   'based',
#   'on',
#   'filters',
#   ',',
#   'basic',
#   'session',
#   'level',
#   'security',
#   ',',
#   'product',
#   'page',
#   ',',
#   'Cart',
#   ',',
#   'share',
#   'button',
#   ',',
#   'empty',
#   'cart',
#   'button',
#   ',',
#   'paginations',
#   'etc',
#   '.',
#   'It',
#   'consists',
#   'of',
#   'a',
#   'separate',
#   'seller',
#   'accounts',
#   'where',
#   'sellers',
#   'can',
#   'register',
#   'and',
#   'later',
#   'upload',
#   'their',
#   'products',
#   'to',
#   'be',
#   'sold',
#   ',',
#   'which',
#   'can',
#   'later',
#   'be',
#   'edited',
#   'or',
#   'deleted',
#   '.',
#   'It',
#   'consists',
#   'of',
#   'an',
#   'admin',
#   'panel',
#   'where',
#   'all',
#   'the',
#   'products',
#   'listed',
#   'can',
#   'be',
#   'viewed',
#   'and',
#   'edited',
#   'by',
#   'the',
#   'moderator',
#   '.',
#   '60',
#   'days',
#   'auto',
#   'delete',
#   'feature',
#   ',',
#   'which',
#   'deletes',
#   'the',
#   'product',
#   'listing',
#   '60',
#   'days',
#   'from',
#   'the',
#   'date',
#   'of',
#   'upload',
#   'if',
#   'seller',
#   'has',
#   'not',
#   'modified',
#   'the',
#   'listing',
#   'upon',
#   'the',
#   'next',
#   'login',
#   '.',
#   'Usage',
#   'of',
#   'Modals',
#   'for',
#   'registration',
#   'and',
#   'Login',
#   'which',
#   'reduces',
#   'the',
#   'number',
#   'of',
#   'pages',
#   'to',
#   'navigate',
#   '.',
#   'Languages',
#   'used',
#   ':',
#   'PHP',
#   ',',
#   'MySQL',
#   ',',
#   'Html',
#   ',',
#   'CSS',
#   ',',
#   'Bootstrap',
#   ',',
#   'JavaScript',
#   'and',
#   'jQuery',
#   '.',
#   'WORK',
#   'EXPERIENCE',
#   'PeopleSoft',
#   'consultant',
#   'Oracle',
#   '-',
#   'September',
#   '2017',
#   'to',
#   'Present',
#   'Performing',
#   'customisations',
#   ',',
#   'enhancements',
#   'and',
#   'bug',
#   'fixes',
#   'for',
#   'front',
#   'end',
#   'and',
#   'backend',
#   'inpeople',
#   'code',
#   'using',
#   'appdesigner',
#   '.',
#   'PeopleSoft',
#   'Consultant',
#   'Oracle',
#   'India',
#   'Ltd',
#   '-',
#   'September',
#   '2017',
#   'to',
#   'April',
#   '2018',
#   '•',
#   'Develop',
#   'customizations',
#   'to',
#   'meet',
#   'business',
#   'process',
#   'requirements',
#   'using',
#   'application',
#   'designer',
#   '.',
#   '•',
#   'Involved',
#   'in',
#   'modification',
#   'enhancement',
#   'and',
#   'bug-fixing',
#   'of',
#   'the',
#   'PeopleSoft',
#   'application',
#   'both',
#   'front',
#   '-',
#   'end',
#   'and',
#   'back-end',
#   'to',
#   'suit',
#   'business',
#   'needs',
#   '.',
#   '•',
#   'Communicate',
#   'with',
#   'the',
#   'business',
#   'and',
#   'get',
#   'clear',
#   'requirements',
#   'if',
#   'adequate',
#   'information',
#   'is',
#   'not',
#   'available',
#   'and',
#   'also',
#   'follow-up',
#   'with',
#   'them',
#   'until',
#   'final',
#   'resolution',
#   'is',
#   'obtained',
#   '.',
#   '•',
#   'Release',
#   'Enhancements',
#   'for',
#   'UAT',
#   'and',
#   'communicate',
#   'with',
#   'business',
#   'to',
#   'migrate',
#   'into',
#   'production',
#   '.',
#   'https://www.indeed.com/r/Nitin-Tr/e7e3a2f5b4c1e24e?isid=rex-download&ikw=download-top&co=IN',
#   '•',
#   'Also',
#   'have',
#   'to',
#   'work',
#   'on',
#   'service',
#   'requests',
#   ',',
#   'Incident',
#   'Creation',
#   ',',
#   'Incident',
#   'Assignment',
#   'additionally',
#   'and',
#   'constantly',
#   'involved',
#   'in',
#   'querying',
#   'the',
#   'database',
#   'and',
#   'running',
#   'reports',
#   '.',
#   'Freelance',
#   'Development',
#   'I',
#   'am',
#   'a',
#   'passionate',
#   'Web',
#   'Developer',
#   'and',
#   'love',
#   'to',
#   'build',
#   'clean',
#   ',',
#   'smooth',
#   'and',
#   'responsive',
#   'websites',
#   '.',
#   'I',
#   'have',
#   'built',
#   'many',
#   'websites',
#   'for',
#   'individuals',
#   'on',
#   'freelance',
#   'or',
#   'per-project',
#   'basis',
#   'which',
#   'are',
#   'Responsive',
#   'in',
#   'nature',
#   '.',
#   'I',
#   'am',
#   'capable',
#   'of',
#   'building',
#   'clean',
#   'and',
#   'responsive',
#   'websites',
#   '.',
#   'They',
#   'include',
#   'personal',
#   'portfolios',
#   'and',
#   'Small',
#   'business',
#   'websites',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/shop',
#   ':',
#   'Responsive',
#   'and',
#   'Dynamic',
#   'e-commerce',
#   'portal',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/tickItBusDemoUrl',
#   ':',
#   'A',
#   'bus',
#   'booking',
#   'platform',
#   ',',
#   'source',
#   ':',
#   'Kathmandu',
#   ',',
#   'Destination',
#   ':',
#   'Pokhra',
#   '.',
#   '•',
#   'http://www.pramodprakash.com/geisle/index.php',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   'focused',
#   'on',
#   'animations',
#   '(',
#   'under',
#   'construction',
#   ')',
#   'also',
#   'check',
#   '(',
#   'geisle/index2.php',
#   ')',
#   '•',
#   'http://pramodprakash.com/fulllogin',
#   ':',
#   'complete',
#   'login',
#   'module',
#   'with',
#   'email',
#   'account',
#   'activation',
#   'and',
#   'password',
#   'reset',
#   '.',
#   '•',
#   'http://pramodprakash.com/sec',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   ',',
#   'built',
#   'to',
#   'showcase',
#   'color',
#   'combinations',
#   'and',
#   'layout',
#   '.',
#   '•',
#   'http://pramodprakash.com/r&d',
#   ':',
#   'A',
#   'small',
#   'business',
#   'website',
#   'built',
#   'in',
#   'parallax',
#   'format',
#   '.',
#   'Completely',
#   'responsive',
#   '.',
#   '•',
#   'http://pramodprakash.com/web1',
#   ':',
#   'A',
#   'template',
#   'built',
#   'according',
#   'to',
#   'given',
#   'specifications',
#   'and',
#   'also',
#   'small',
#   'map',
#   'feature',
#   'included',
#   'which',
#   'also',
#   'supports',
#   'location',
#   'search',
#   '.',
#   'EDUCATION',
#   'Btech',
#   'information',
#   'science',
#   'in',
#   'BCET',
#   'Vtu',
#   '-',
#   'Bengaluru',
#   ',',
#   'Karnataka',
#   '2017',
#   'Vijaya',
#   'composite',
#   'p.u',
#   '.',
#   'college',
#   'e-commerce',
#   'Vijaya',
#   'High',
#   'School',
#   'SKILLS',
#   'Php',
#   ',',
#   'Html5',
#   ',',
#   'Javascript',
#   ',',
#   'Css',
#   ',',
#   'Bootstrap',
#   ',',
#   'Jquery',
#   ',',
#   'Sql',
#   'LINKS',
#   'https://www.linkedin.com/in/nitin-tr-588105129',
#   'ADDITIONAL',
#   'INFORMATION',
#   'Software',
#   'Skills',
#   'https://www.linkedin.com/in/nitin-tr-588105129',
#   '•',
#   'Programming',
#   'Language',
#   ':',
#   'core',
#   'java',
#   ',',
#   'peoplecode',
#   '.',
#   '•',
#   'Scripting',
#   'languages',
#   ':',
#   'PHP',
#   ',',
#   'JavaScript',
#   '.',
#   '•',
#   'Web',
#   'Languages',
#   ':',
#   'HTML',
#   ',',
#   'CSS',
#   '.',
#   '•',
#   'Database',
#   'Language',
#   ':',
#   'Sql',
#   '.',
#   '•',
#   'Frameworks',
#   ':',
#   'Bootstrap',
#   ',',
#   'JQuery',
#   '.',
#   '•',
#   "IDE's",
#   ':',
#   'NetBeans',
#   ',',
#   'Eclipse',
#   '.',
#   '•',
#   'Tools',
#   ':',
#   'Application',
#   'Designer',
#   ',',
#   'Toad',
#   '.',
#   'Personal',
#   'Skills',
#   '•',
#   'Excellent',
#   'Communication',
#   'Skills',
#   'both',
#   'Written',
#   'and',
#   'verbal',
#   '.',
#   '•',
#   'Honest',
#   ',',
#   'trustworthy',
#   'and',
#   'highly',
#   'motivated',
#   'team',
#   'player',
#   'and',
#   'Strong',
#   'Negotiator',
#   '.',
#   '•',
#   'Supportive',
#   'and',
#   'creative',
#   '.',
#   '•',
#   'Quick',
#   'Learner',
#   'and',
#   'Flexible',
#   '.',
#   '•',
#   'Good',
#   'Analytical',
#   'Ability',
#   'and',
#   'Logical',
#   'Reasoning',
#   '.',
#   '•',
#   'Good',
#   'listening',
#   'skills',
#   '.']}
